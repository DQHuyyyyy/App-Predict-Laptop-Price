# %% [markdown]
# ## LAPTOP PRICE PRIDICTION NEW DATA

# %%
import warnings

# Tắt tất cả các cảnh báo
warnings.filterwarnings("ignore")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('LaptopPrice_Final.csv')

# %%
df.head()
# Out:
#   Brands  OpSys  ScrSize                       ScrResolution  \
# 0  APPLE  macOS     13.3  IPS Panel Retina Display 2560x1600
# 1  APPLE  macOS     13.3                            1440x900
# 2     HP  macOS     15.6                   Full HD 1920x1080
# 3  APPLE  macOS     15.4  IPS Panel Retina Display 2880x1800
# 4  APPLE  macOS     13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  Weight   Price
# 0  Intel Iris Plus Graphics 640  1.37kg   861.0
# 1        Intel HD Graphics 6000  1.34kg   578.0
# 2         Intel HD Graphics 620  1.86kg   369.0
# 3            AMD Radeon Pro 455  1.83kg  1630.0
# ...

# %%
df.shape
# Out:
# (1448, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1448 entries, 0 to 1447
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Brands         1448 non-null   object
#  1   OpSys          1448 non-null   object
#  2   ScrSize        1448 non-null   float64
#  3   ScrResolution  1448 non-null   object
#  4   Cpu            1448 non-null   object
#  5   Ram            1448 non-null   object
#  6   Memory         1448 non-null   object
#  7   Gpu            1448 non-null   object
#  8   Weight         1448 non-null   object
#  9   Price          1434 non-null   float64
# dtypes: float64(2), object(8)
# memory usage: 113.2+ KB

# %%
df.isnull().sum()
# Out:
# Brands            0
# OpSys             0
# ScrSize           0
# ScrResolution     0
# Cpu               0
# Ram               0
# Memory            0
# Gpu               0
# Weight            0
# Price            14
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (1434, 10)

# %%
df.isnull().sum()
# Out:
# Brands           0
# OpSys            0
# ScrSize          0
# ScrResolution    0
# Cpu              0
# Ram              0
# Memory           0
# Gpu              0
# Weight           0
# Price            0
# dtype: int64

# %%
df.head()
# Out:
#   Brands  OpSys  ScrSize                       ScrResolution  \
# 0  APPLE  macOS     13.3  IPS Panel Retina Display 2560x1600
# 1  APPLE  macOS     13.3                            1440x900
# 2     HP  macOS     15.6                   Full HD 1920x1080
# 3  APPLE  macOS     15.4  IPS Panel Retina Display 2880x1800
# 4  APPLE  macOS     13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  Weight   Price
# 0  Intel Iris Plus Graphics 640  1.37kg   861.0
# 1        Intel HD Graphics 6000  1.34kg   578.0
# 2         Intel HD Graphics 620  1.86kg   369.0
# 3            AMD Radeon Pro 455  1.83kg  1630.0
# ...

# %%
df['Ram'] = df['Ram'].str.replace('GB','')
df['Weight'] = df['Weight'].str.replace('kg','')

# %%
df.head()
# Out:
#   Brands  OpSys  ScrSize                       ScrResolution  \
# 0  APPLE  macOS     13.3  IPS Panel Retina Display 2560x1600
# 1  APPLE  macOS     13.3                            1440x900
# 2     HP  macOS     15.6                   Full HD 1920x1080
# 3  APPLE  macOS     15.4  IPS Panel Retina Display 2880x1800
# 4  APPLE  macOS     13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu Weight   Price
# 0  Intel Iris Plus Graphics 640   1.37   861.0
# 1        Intel HD Graphics 6000   1.34   578.0
# 2         Intel HD Graphics 620   1.86   369.0
# 3            AMD Radeon Pro 455   1.83  1630.0
# ...

# %%
df['Ram'] = df['Ram'].astype('int32')
df['Weight'] = df['Weight'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1434 entries, 0 to 1447
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Brands         1434 non-null   object
#  1   OpSys          1434 non-null   object
#  2   ScrSize        1434 non-null   float64
#  3   ScrResolution  1434 non-null   object
#  4   Cpu            1434 non-null   object
#  5   Ram            1434 non-null   int32
#  6   Memory         1434 non-null   object
#  7   Gpu            1434 non-null   object
#  8   Weight         1434 non-null   float32
#  9   Price          1434 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(6)
# memory usage: 112.0+ KB

# %%
import seaborn as sns

# %%
sns.distplot(df['Price']) #mật độ của Price
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
df['Brands'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
    sns.barplot(x=df['Brands'],y=df['Price'])
    plt.xticks(rotation='vertical')
    plt.show()

# %%
sns.distplot(df['ScrSize'])
# Out:
# <AxesSubplot:xlabel='ScrSize', ylabel='Density'>

# %%
#Scatter Plot: Biểu đồ phân tán
sns.scatterplot(x=df['ScrSize'],y=df['Price'])
# Out:
# <AxesSubplot:xlabel='ScrSize', ylabel='Price'>

# %%
df['ScrResolution'].value_counts()
# Out:
# Full HD 1920x1080                                502
# 1366x768                                         277
# IPS Panel Full HD 1920x1080                      229
# 1920 x 1080                                       82
# IPS Panel Full HD / Touchscreen 1920x1080         52
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# 2560 x 1600                                       19
# 1920 x 1200                                       17
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 1920x1080                                          7
# 2880 x 1800                                        7
# IPS Panel 1366x768                                 7
# 2560 x 1440                                        7
# ...

# %%
df['Touchscreen'] = df['ScrResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
df.sample(5)
# Out:
#      Brands       OpSys  ScrSize      ScrResolution  \
# 602    ACER  Windows 10     14.0  Full HD 1920x1080
# 1200   DELL  Windows 10     15.6           1366x768
# 40     ASUS       Linux     15.6  Full HD 1920x1080
# 1164     HP       macOS     15.6           1366x768
# 1235     HP  Windows 10     15.6  Full HD 1920x1080
#
#                                        Cpu  Ram              Memory  \
# 602   Intel Celeron Quad Core N3450 1.1GHz    4  32GB Flash Storage
# 1200            Intel Core i3 6006U 2.0GHz    4           128GB SSD
# 40                Intel Core i3 6006U 2GHz    4             1TB HDD
# 1164            Intel Core i5 6200U 2.3GHz    4           500GB HDD
# 1235              Intel Core i3 6006U 2GHz    4             1TB HDD
#
#                         Gpu  Weight  Price  Touchscreen
# 602   Intel HD Graphics 500     1.6  211.0            0
# 1200     AMD Radeon R7 M440     2.3  321.0            0
# 40    Intel HD Graphics 620     2.0  250.0            0
# ...

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price'])
# Out:
# <AxesSubplot:xlabel='Touchscreen', ylabel='Price'>

# %%
df['Ips'] = df['ScrResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
df.head()
# Out:
#   Brands  OpSys  ScrSize                       ScrResolution  \
# 0  APPLE  macOS     13.3  IPS Panel Retina Display 2560x1600
# 1  APPLE  macOS     13.3                            1440x900
# 2     HP  macOS     15.6                   Full HD 1920x1080
# 3  APPLE  macOS     15.4  IPS Panel Retina Display 2880x1800
# 4  APPLE  macOS     13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  Weight   Price  Touchscreen  Ips
# 0  Intel Iris Plus Graphics 640    1.37   861.0            0    1
# 1        Intel HD Graphics 6000    1.34   578.0            0    0
# ...

# %%
df['Ips'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['Ips'],y=df['Price'])
# Out:
# <AxesSubplot:xlabel='Ips', ylabel='Price'>

# %%
new = df['ScrResolution'].str.split('x',n=1,expand=True)

# %%
df['X_res'] = new[0]
df['Y_res'] = new[1]

# %%
df.sample(5)
# Out:
#       Brands            OpSys  ScrSize  \
# 260     DELL       Windows 10     17.3
# 1425     MSI  Windows 11 Home     17.3
# 82        HP       Windows 10     14.0
# 904   LENOVO       Windows 10     15.6
# 1271  LENOVO       Windows 10     13.3
#
#                                    ScrResolution                         Cpu  \
# 260                            Full HD 1920x1080  Intel Core i7 8550U 1.8GHz
# 1425                                 2560 x 1440               Intel Core i9
# 82                             Full HD 1920x1080  Intel Core i5 8250U 1.6GHz
# 904                  IPS Panel Full HD 1920x1080  Intel Core i5 7200U 2.5GHz
# 1271  IPS Panel Quad HD+ / Touchscreen 3200x1800  Intel Core i7 6500U 2.5GHz
#
#       Ram                Memory                      Gpu  Weight   Price  \
# 260     8  128GB SSD +  1TB HDD           AMD Radeon 530    2.80   734.0
# 1425   32                 32 GB  NVIDIA GeForce RTX 4080    4.30  2791.0
# ...

# %%
df['X_res'] = df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df.head()
# Out:
#   Brands  OpSys  ScrSize                       ScrResolution  \
# 0  APPLE  macOS     13.3  IPS Panel Retina Display 2560x1600
# 1  APPLE  macOS     13.3                            1440x900
# 2     HP  macOS     15.6                   Full HD 1920x1080
# 3  APPLE  macOS     15.4  IPS Panel Retina Display 2880x1800
# 4  APPLE  macOS     13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  Weight   Price  Touchscreen  Ips X_res Y_res
# 0  Intel Iris Plus Graphics 640    1.37   861.0            0    1  2560  1600
# 1        Intel HD Graphics 6000    1.34   578.0            0    0  1440   900
# ...

# %%
df['X_res'] = df['X_res'].astype('int')
df['Y_res'] = df['Y_res'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1434 entries, 0 to 1447
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Brands         1434 non-null   object
#  1   OpSys          1434 non-null   object
#  2   ScrSize        1434 non-null   float64
#  3   ScrResolution  1434 non-null   object
#  4   Cpu            1434 non-null   object
#  5   Ram            1434 non-null   int32
#  6   Memory         1434 non-null   object
#  7   Gpu            1434 non-null   object
#  8   Weight         1434 non-null   float32
#  9   Price          1434 non-null   float64
#  10  Touchscreen    1434 non-null   int64
#  11  Ips            1434 non-null   int64
#  12  X_res          1434 non-null   int32
#  13  Y_res          1434 non-null   int32
# dtypes: float32(1), float64(2), int32(3), int64(2), object(6)
# memory usage: 145.6+ KB

# %%
#Correlation: hệ số tg quan(-1,1)
df.corr()['Price']
# Out:
# ScrSize        0.106181
# Ram            0.627617
# Weight         0.326917
# Price          1.000000
# Touchscreen    0.120233
# Ips            0.146457
# X_res          0.528847
# Y_res          0.530427
# Name: Price, dtype: float64

# %%
df['ppi'] = (((df['X_res']**2) + (df['Y_res']**2))**0.5/df['ScrSize']).astype('float')

# %%
df.corr()['Price']
# Out:
# ScrSize        0.106181
# Ram            0.627617
# Weight         0.326917
# Price          1.000000
# Touchscreen    0.120233
# Ips            0.146457
# X_res          0.528847
# Y_res          0.530427
# ppi            0.440181
# Name: Price, dtype: float64

# %%
df.drop(columns=['ScrResolution'],inplace=True)

# %%
df.head()
# Out:
#   Brands  OpSys  ScrSize                         Cpu  Ram  \
# 0  APPLE  macOS     13.3        Intel Core i5 2.3GHz    8
# 1  APPLE  macOS     13.3        Intel Core i5 1.8GHz    8
# 2     HP  macOS     15.6  Intel Core i5 7200U 2.5GHz    8
# 3  APPLE  macOS     15.4        Intel Core i7 2.7GHz   16
# 4  APPLE  macOS     13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  Weight   Price  \
# 0            128GB SSD  Intel Iris Plus Graphics 640    1.37   861.0
# 1  128GB Flash Storage        Intel HD Graphics 6000    1.34   578.0
# 2            256GB SSD         Intel HD Graphics 620    1.86   369.0
# 3            512GB SSD            AMD Radeon Pro 455    1.83  1630.0
# 4            256GB SSD  Intel Iris Plus Graphics 650    1.37  1159.0
#
#    Touchscreen  Ips  X_res  Y_res         ppi
# 0            0    1   2560   1600  226.983005
# 1            0    0   1440    900  127.677940
# 2            0    0   1920   1080  141.211998
# ...

# %%
df.drop(columns=['ScrSize','X_res','Y_res'],inplace=True)

# %%
df.head()
# Out:
#   Brands  OpSys                         Cpu  Ram               Memory  \
# 0  APPLE  macOS        Intel Core i5 2.3GHz    8            128GB SSD
# 1  APPLE  macOS        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2     HP  macOS  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3  APPLE  macOS        Intel Core i7 2.7GHz   16            512GB SSD
# 4  APPLE  macOS        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  Weight   Price  Touchscreen  Ips         ppi
# 0  Intel Iris Plus Graphics 640    1.37   861.0            0    1  226.983005
# 1        Intel HD Graphics 6000    1.34   578.0            0    0  127.677940
# 2         Intel HD Graphics 620    1.86   369.0            0    0  141.211998
# 3            AMD Radeon Pro 455    1.83  1630.0            0    1  220.534624
# 4  Intel Iris Plus Graphics 650    1.37  1159.0            0    1  226.983005

# %%
df['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz     188
# Intel Core i7 7700HQ 2.8GHz    146
# Intel Core i7 7500U 2.7GHz     132
# Intel Core i5 8250U 1.6GHz      72
# Intel Core i7 8550U 1.8GHz      72
#                               ...
# Intel Core i5 7200U 2.70GHz      1
# Intel Core i5 7200U 2.7GHz       1
# AMD E-Series 9000e 1.5GHz        1
# Intel Core M m3-7Y30 2.2GHz      1
# Intel Core i7-8665U              1
# Name: Cpu, Length: 146, dtype: int64

# %%
df['Cpu Name'] = df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#   Brands  OpSys                         Cpu  Ram               Memory  \
# 0  APPLE  macOS        Intel Core i5 2.3GHz    8            128GB SSD
# 1  APPLE  macOS        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2     HP  macOS  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3  APPLE  macOS        Intel Core i7 2.7GHz   16            512GB SSD
# 4  APPLE  macOS        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  Weight   Price  Touchscreen  Ips         ppi  \
# 0  Intel Iris Plus Graphics 640    1.37   861.0            0    1  226.983005
# 1        Intel HD Graphics 6000    1.34   578.0            0    0  127.677940
# 2         Intel HD Graphics 620    1.86   369.0            0    0  141.211998
# 3            AMD Radeon Pro 455    1.83  1630.0            0    1  220.534624
# 4  Intel Iris Plus Graphics 650    1.37  1159.0            0    1  226.983005
#
#         Cpu Name
# 0  Intel Core i5
# 1  Intel Core i5
# 2  Intel Core i5
# ...

# %%
def fetch_processor(text):
    if text == 'Intel Core i9' or text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3' or text == 'Ryzen 5' or text == 'Ryzen 7' or text == 'Ryzen 9':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['Cpu brand'] = df['Cpu Name'].apply(fetch_processor)

# %%
df.head()
# Out:
#   Brands  OpSys                         Cpu  Ram               Memory  \
# 0  APPLE  macOS        Intel Core i5 2.3GHz    8            128GB SSD
# 1  APPLE  macOS        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2     HP  macOS  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3  APPLE  macOS        Intel Core i7 2.7GHz   16            512GB SSD
# 4  APPLE  macOS        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  Weight   Price  Touchscreen  Ips         ppi  \
# 0  Intel Iris Plus Graphics 640    1.37   861.0            0    1  226.983005
# 1        Intel HD Graphics 6000    1.34   578.0            0    0  127.677940
# 2         Intel HD Graphics 620    1.86   369.0            0    0  141.211998
# 3            AMD Radeon Pro 455    1.83  1630.0            0    1  220.534624
# 4  Intel Iris Plus Graphics 650    1.37  1159.0            0    1  226.983005
#
#         Cpu Name      Cpu brand
# 0  Intel Core i5  Intel Core i5
# ...

# %%
df['Cpu brand'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['Cpu brand'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Cpu','Cpu Name'],inplace=True)

# %%
df.head()
# Out:
#   Brands  OpSys  Ram               Memory                           Gpu  \
# 0  APPLE  macOS    8            128GB SSD  Intel Iris Plus Graphics 640
# 1  APPLE  macOS    8  128GB Flash Storage        Intel HD Graphics 6000
# 2     HP  macOS    8            256GB SSD         Intel HD Graphics 620
# 3  APPLE  macOS   16            512GB SSD            AMD Radeon Pro 455
# 4  APPLE  macOS    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    Weight   Price  Touchscreen  Ips         ppi      Cpu brand
# 0    1.37   861.0            0    1  226.983005  Intel Core i5
# 1    1.34   578.0            0    0  127.677940  Intel Core i5
# 2    1.86   369.0            0    0  141.211998  Intel Core i5
# 3    1.83  1630.0            0    1  220.534624  Intel Core i7
# 4    1.37  1159.0            0    1  226.983005  Intel Core i5

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['Ram'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Memory'].value_counts()
# Out:
# 256GB SSD                        409
# 1TB HDD                          221
# 500GB HDD                        129
# 512GB SSD                        116
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         75
# 256GB SSD +  1TB HDD              72
# 512GB                             58
# 32GB Flash Storage                38
# 1 TB                              29
# 512 GB                            18
# 2TB HDD                           16
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 64GB Flash Storage                14
# 32 GB                             12
# 16 GB                             12
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 8 GB                               5
# 256 GB                             4
# ...

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')
new = df["Memory"].str.split("+", n = 1, expand = True)

df["first"]= new[0]
df["first"]=df["first"].str.strip()

df["second"]= new[1]

df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['first'] = df['first'].str.replace(r'\D', '')

df["second"].fillna("0", inplace = True)

df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['second'] = df['second'].str.replace(r'\D', '')

df["first"] = df["first"].astype(int)
df["second"] = df["second"].astype(int)

df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
df["SSD"]=(df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])
df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
df["Flash_Storage"]=(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])

df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)

# %%
df.sample(5)
# Out:
#      Brands       OpSys  Ram             Memory                    Gpu  \
# 29       HP  Windows 10    8           1000 HDD   NVIDIA GeForce 930MX
# 661  LENOVO  Windows 10    4            500 HDD  Intel HD Graphics 500
# 512    DELL  Windows 10    8           1000 HDD  Intel HD Graphics 620
# 319    ACER  Windows 10    4  128 Flash Storage  Intel HD Graphics 405
# 946    DELL  Windows 10    8            256 SSD      Intel HD Graphics
#
#      Weight  Price  Touchscreen  Ips         ppi              Cpu brand   HDD  \
# 29     2.50  576.0            0    0  127.335675          Intel Core i5  1000
# 661    2.20  269.0            0    0  100.454670  Other Intel Processor   500
# 512    2.18  537.0            0    0  141.211998          Intel Core i5  1000
# 319    1.40  312.0            0    0  135.094211  Other Intel Processor     0
# 946    1.36  946.0            1    0  176.232574          Intel Core i5     0
#
#      SSD  Hybrid  Flash_Storage
# 29     0       0              0
# ...

# %%
df.drop(columns=['Memory'],inplace=True)

# %%
df.head()
# Out:
#   Brands  OpSys  Ram                           Gpu  Weight   Price  \
# 0  APPLE  macOS    8  Intel Iris Plus Graphics 640    1.37   861.0
# 1  APPLE  macOS    8        Intel HD Graphics 6000    1.34   578.0
# 2     HP  macOS    8         Intel HD Graphics 620    1.86   369.0
# 3  APPLE  macOS   16            AMD Radeon Pro 455    1.83  1630.0
# 4  APPLE  macOS    8  Intel Iris Plus Graphics 650    1.37  1159.0
#
#    Touchscreen  Ips         ppi      Cpu brand  HDD  SSD  Hybrid  \
# 0            0    1  226.983005  Intel Core i5    0  128       0
# 1            0    0  127.677940  Intel Core i5    0    0       0
# 2            0    0  141.211998  Intel Core i5    0  256       0
# 3            0    1  220.534624  Intel Core i7    0  512       0
# 4            0    1  226.983005  Intel Core i5    0  256       0
#
#    Flash_Storage
# 0              0
# 1            128
# 2              0
# 3              0
# 4              0

# %%
df.corr()['Price']
# Out:
# Ram              0.627617
# Weight           0.326917
# Price            1.000000
# Touchscreen      0.120233
# Ips              0.146457
# ppi              0.440181
# HDD             -0.159414
# SSD              0.448838
# Hybrid          -0.002078
# Flash_Storage   -0.048524
# Name: Price, dtype: float64

# %%
df.drop(columns=['Hybrid','Flash_Storage','HDD'],inplace=True)

# %%
df.head()
# Out:
#   Brands  OpSys  Ram                           Gpu  Weight   Price  \
# 0  APPLE  macOS    8  Intel Iris Plus Graphics 640    1.37   861.0
# 1  APPLE  macOS    8        Intel HD Graphics 6000    1.34   578.0
# 2     HP  macOS    8         Intel HD Graphics 620    1.86   369.0
# 3  APPLE  macOS   16            AMD Radeon Pro 455    1.83  1630.0
# 4  APPLE  macOS    8  Intel Iris Plus Graphics 650    1.37  1159.0
#
#    Touchscreen  Ips         ppi      Cpu brand  SSD
# 0            0    1  226.983005  Intel Core i5  128
# 1            0    0  127.677940  Intel Core i5    0
# 2            0    0  141.211998  Intel Core i5  256
# 3            0    1  220.534624  Intel Core i7  512
# 4            0    1  226.983005  Intel Core i5  256

# %%
df['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620      278
# Intel HD Graphics 520      183
# Intel UHD Graphics 620      67
# NVIDIA GeForce GTX 1050     66
# NVIDIA GeForce GTX 1060     48
#                           ...
# AMD FirePro W4190M           1
# AMD FirePro W6150M           1
# AMD Radeon R5 M315           1
# NVIDIA Quadro M500M          1
# NVIDIA GeForce GTX1060       1
# Name: Gpu, Length: 136, dtype: int64

# %%
df['Gpu brand'] = df['Gpu'].apply(lambda x:x.split()[0])

# %%
df['Gpu brand'].value_counts()
# Out:
# Intel     767
# NVIDIA    460
# AMD       185
# Null       19
# ARM         1
# Radeon      1
# NVDIA       1
# Name: Gpu brand, dtype: int64

# %%
df = df[df['Gpu brand'] != 'ARM']
df = df[df['Gpu brand'] != 'Null']
df = df[df['Gpu brand'] != 'Radeon']
df = df[df['Gpu brand'] != 'NVDIA']

# %%
df['Gpu brand'].value_counts()
# Out:
# Intel     767
# NVIDIA    460
# AMD       185
# Name: Gpu brand, dtype: int64

# %%
sns.barplot(x=df['Gpu brand'],y=df['Price'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Gpu'],inplace=True)

# %%
df.head()
# Out:
#   Brands  OpSys  Ram  Weight   Price  Touchscreen  Ips         ppi  \
# 0  APPLE  macOS    8    1.37   861.0            0    1  226.983005
# 1  APPLE  macOS    8    1.34   578.0            0    0  127.677940
# 2     HP  macOS    8    1.86   369.0            0    0  141.211998
# 3  APPLE  macOS   16    1.83  1630.0            0    1  220.534624
# 4  APPLE  macOS    8    1.37  1159.0            0    1  226.983005
#
#        Cpu brand  SSD Gpu brand
# 0  Intel Core i5  128     Intel
# 1  Intel Core i5    0     Intel
# 2  Intel Core i5  256     Intel
# 3  Intel Core i7  512       AMD
# 4  Intel Core i5  256     Intel

# %%
df['OpSys'].value_counts()
# Out:
# Windows 10         1064
# Windows 11 Home      81
# macOS                79
# Linux                61
# Windows 7            44
# Windows 11 Pro       29
# Chrome OS            28
# Mac OS X              8
# Windows 10 S          7
# Windows 10 Pro        4
# Windows 10 Home       3
# Windows 11 S          3
# Android               1
# Name: OpSys, dtype: int64

# %%
sns.barplot(x=df['OpSys'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S' or inp == 'Windows 11 Pro'or inp == 'Windows 11 Home' or inp == 'Windows 11 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Other'

# %%
df['Os'] = df['OpSys'].apply(cat_os)

# %%
df.head()
# Out:
#   Brands  OpSys  Ram  Weight   Price  Touchscreen  Ips         ppi  \
# 0  APPLE  macOS    8    1.37   861.0            0    1  226.983005
# 1  APPLE  macOS    8    1.34   578.0            0    0  127.677940
# 2     HP  macOS    8    1.86   369.0            0    0  141.211998
# 3  APPLE  macOS   16    1.83  1630.0            0    1  220.534624
# 4  APPLE  macOS    8    1.37  1159.0            0    1  226.983005
#
#        Cpu brand  SSD Gpu brand   Os
# 0  Intel Core i5  128     Intel  Mac
# 1  Intel Core i5    0     Intel  Mac
# 2  Intel Core i5  256     Intel  Mac
# 3  Intel Core i7  512       AMD  Mac
# 4  Intel Core i5  256     Intel  Mac

# %%
sns.barplot(x=df['Os'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df['Weight'])
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='Density'>

# %%
sns.scatterplot(x=df['Weight'],y=df['Price'])
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='Price'>

# %%
df.corr()['Price']
# Out:
# Ram            0.635602
# Weight         0.317273
# Price          1.000000
# Touchscreen    0.127835
# Ips            0.156347
# ppi            0.447429
# SSD            0.466589
# Name: Price, dtype: float64

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.distplot(np.log(df['Price']))
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
X = df.drop(columns=['Price'])
y = df['Price']
#df.drop(columns=)

# %%
df
# Out:
#        Brands            OpSys  Ram  Weight   Price  Touchscreen  Ips  \
# 0       APPLE            macOS    8    1.37   861.0            0    1
# 1       APPLE            macOS    8    1.34   578.0            0    0
# 2          HP            macOS    8    1.86   369.0            0    0
# 3       APPLE            macOS   16    1.83  1630.0            0    1
# 4       APPLE            macOS    8    1.37  1159.0            0    1
# ...       ...              ...  ...     ...     ...          ...  ...
# 1443  SAMSUNG   Windows 11 Pro   32    3.20  1399.0            0    0
# 1444     ASUS  Windows 11 Home   16    3.75   989.0            0    0
# 1445     ASUS  Windows 11 Home   32    4.55  1949.0            0    0
# 1446       LG  Windows 11 Home    8    2.20  1065.0            0    0
# 1447       LG  Windows 11 Home   16    2.83   899.0            0    0
#
#              ppi              Cpu brand  SSD Gpu brand       Os
# ...

# %%
X
# Out:
#        Brands            OpSys  Ram  Weight  Touchscreen  Ips         ppi  \
# 0       APPLE            macOS    8    1.37            0    1  226.983005
# 1       APPLE            macOS    8    1.34            0    0  127.677940
# 2          HP            macOS    8    1.86            0    0  141.211998
# 3       APPLE            macOS   16    1.83            0    1  220.534624
# 4       APPLE            macOS    8    1.37            0    1  226.983005
# ...       ...              ...  ...     ...          ...  ...         ...
# 1443  SAMSUNG   Windows 11 Pro   32    3.20            0    0  212.264575
# 1444     ASUS  Windows 11 Home   16    3.75            0    0  193.517562
# 1445     ASUS  Windows 11 Home   32    4.55            0    0  234.222980
# 1446       LG  Windows 11 Home    8    2.20            0    0  157.350512
# 1447       LG  Windows 11 Home   16    2.83            0    0  188.679623
#
#                   Cpu brand  SSD Gpu brand       Os
# ...

# %%
y
# Out:
# 0        861.0
# 1        578.0
# 2        369.0
# 3       1630.0
# 4       1159.0
#          ...
# 1443    1399.0
# 1444     989.0
# 1445    1949.0
# 1446    1065.0
# 1447     899.0
# Name: Price, Length: 1412, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

# %%
X_train
# Out:
#       Brands       OpSys  Ram  Weight  Touchscreen  Ips         ppi  \
# 1158  LENOVO  Windows 10    8    2.50            0    0  141.211998
# 681     ASUS  Windows 10    4    1.86            0    0  100.454670
# 660     DELL  Windows 10    8    1.56            0    0  157.350512
# 293     DELL  Windows 10    8    2.00            0    0  141.211998
# 480     DELL  Windows 10    8    2.16            0    1  141.211998
# ...      ...         ...  ...     ...          ...  ...         ...
# 474     ASUS  Windows 10   12    2.06            0    1  282.423996
# 306       HP  Windows 10   16    1.28            1    0  165.632118
# 501       HP  Windows 10    8    1.91            0    0  100.454670
# 535     DELL  Windows 10    8    1.93            0    0  141.211998
# 1207  LENOVO  Windows 10    4    2.20            0    0  100.454670
#
#                   Cpu brand  SSD Gpu brand       Os
# 1158          Intel Core i5    0       AMD  Windows
# ...

# %%
y_train
# Out:
# 1158     507.0
# 681      269.0
# 660      790.0
# 293     1175.0
# 480      811.0
#          ...
# 474      835.0
# 306     1269.0
# 501      398.0
# 535      880.0
# 1207     192.0
# Name: Price, Length: 1200, dtype: float64

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,StackingRegressor
from sklearn.svm import SVR

# %% [markdown]
# # Linear Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,9,10])
],remainder='passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.6241559052341581
# MAE 185.8144979095826

# %% [markdown]
# # Lasso Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,9,10])
],remainder='passthrough')

step2 = Lasso(alpha=0.001)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.6241714169889234
# MAE 185.7940461636116

# %% [markdown]
# # Decision Tree

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,9,10])
],remainder='passthrough')

step2 = DecisionTreeRegressor(max_depth=8)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.5749397594153396
# MAE 185.1000404106536

# %% [markdown]
# # SVM

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,9,10])
],remainder='passthrough')

step2 = SVR(kernel='rbf',C=10000,epsilon=0.1)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.5774805955163884
# MAE 200.15190028167572

# %% [markdown]
# # Random Forest

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,9,10])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.6911557608779902
# MAE 145.94814745214666

# %% [markdown]
# # Voting Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse=False, drop='first'), [0, 1, 7,9, 10])
], remainder='passthrough')

# Base models
base_models = [
    ('linear', LinearRegression()),
    ('lasso', Lasso(alpha=0.001)),
    ('decision_tree', DecisionTreeRegressor(max_depth=8)),
    ('svm', SVR(kernel='rbf', C=10000, epsilon=0.1)),
    ('random_forest', RandomForestRegressor(n_estimators=100, random_state=3, max_samples=0.5, max_features=0.75, max_depth=15))
]

# Meta model
meta_model = LinearRegression() # phù hợp với dữ liệu ít và cho hiệu suất cao hơn so vưới 4model
#meta_model = SVR()

# Stacking Regressor
stacking_reg = StackingRegressor(estimators=base_models, final_estimator=meta_model)
#estimators giúp chọn model trong base_md, chọn Random Forest
# Pipeline
pipe = Pipeline([
    ('step1', step1),
    ('step2', stacking_reg)
])

# Fit and predict
pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)

# Evaluate
print('R2 score', r2_score(y_test, y_pred))
print('MAE', mean_absolute_error(y_test, y_pred))
# Out:
# R2 score 0.7049248238651451
# MAE 144.59529665567385

# %% [markdown]
# # EXport df và model

# %%
import joblib 
#joblib.dump()
#df.to_csv('data_laptop_.csv')
joblib.dump(pipe,open('stacked_model_06.joblib','wb'))

# %%
X_train

# %% [markdown]
# # EDIT BẢN NÀY

# %%
import pandas as pd
from tkinter import *
from tkinter import ttk 
import joblib

# Load the dataset
df = pd.read_csv(r'C:\Users\huy\HUYYYYYYYY\data_laptop.csv')

# Load the pre-trained model
model = joblib.load(r'C:/Users/huy/HUYYYYYYYY/stacked_model_06.joblib')

# Create Tkinter window
window = Tk()
window.title("Laptop Price Predictor")

# Function to predict price
def predict_price():
    # Prepare input data for prediction
    input_data = {
        'Brands': company.get(),
        'OpSys': os.get(),
        'Ram': ram.get(),
        'Weight': weight.get(),
        'Touchscreen': touchscreen.get(),
        'Ips': ips.get(),
        'ppi': ppi.get(),
        'Cpu brand': cpu_brand.get(),
        'SSD': ssd.get(),
        'Gpu brand': gpu_brand.get(),
        'Os': os_detail.get()
    }

    # Create a DataFrame with the input data
    input_df = pd.DataFrame([input_data])

    #Make prediction
    try:
        predicted_price = model.predict(input_df)
        result_label.config(text=f'Predicted Price: ${predicted_price[0]:,.2f}')
    


    except Exception as e:
        result_label.config(text=f'Error: {str(e)}')

# Create and place widgets

#Brand
company_label = ttk.Label(window, text="Brand:")
company_label.grid(row=0, column=0,padx=5,pady=5)
company = ttk.Combobox(window,values=['DELL','APPLE','ASUS','ACER','HP','LENOVO','MSI'])
company.grid(row=0, column=1)

#OS
os_detail_label = ttk.Label(window, text="OpSystem:")
os_detail_label.grid(row=1, column=0,padx=5,pady=5)
os_detail =ttk.Combobox(window,values=['Windows','Mac'])
os_detail.grid(row=1, column=1)

#OpSYS DEtail
os_label = ttk.Label(window, text="System Detail:")
os_label.grid(row=2, column=0,padx=5,pady=5)
os = ttk.Combobox(window,values=['Windows 11 Home','Windows 11 Pro','Windows 11 S','Windows 10','Windows 7','macOS','Linux'])
os.grid(row=2, column=1)

#RAM
ram_label = ttk.Label(window, text="RAM (GB):")
ram_label.grid(row=3, column=0,padx=5,pady=5)
ram = ttk.Combobox(window,values=[32,16,8])
ram.grid(row=3, column=1)

#Weight
weight_label = Label(window, text="Weight:")
weight_label.grid(row=4, column=0,padx=5,pady=5)
weight = Entry(window)
weight.grid(row=4, column=1)

#TouchScreen
touchscreen_label = ttk.Label(window, text="Touchscreen:")
touchscreen_label.grid(row=5, column=0,padx=5,pady=5)
touchscreen = ttk.Combobox(window,values=[1,0])
touchscreen.grid(row=5, column=1)

#IPS
ips_label = ttk.Label(window, text="IPS:")
ips_label.grid(row=6, column=0,padx=5,pady=5)
ips = ttk.Combobox(window,values=[1,0])
ips.grid(row=6, column=1)

#PPI
ppi_label = Label(window, text="PPI:")
ppi_label.grid(row=7, column=0,padx=5,pady=5)
ppi = Entry(window)
ppi.grid(row=7, column=1)

#CPU
cpu_brand_label = ttk.Label(window, text="CPU Brand:")
cpu_brand_label.grid(row=8, column=0,padx=5,pady=5)
cpu_brand = ttk.Combobox(window,values=['Ryzen 7','Ryzen 5','Intel Core i9','Intel Core i7','Intel Core i5','Other'])
cpu_brand.grid(row=8, column=1)

#SSD
ssd_label =ttk.Label(window, text="SSD")
ssd_label.grid(row=9, column=0,padx =5,pady=5)
ssd = ttk.Combobox(window,values=[0,8,128,256,512,1024])
ssd.grid(row=9, column=1,padx=5,pady=5)

#GPU
gpu_brand_label = ttk.Label(window, text="GPU Brand:")
gpu_brand_label.grid(row=10, column=0,padx=5,pady=5)
gpu_brand = ttk.Combobox(window,values=['Intel','AMD','NVIDIA',])
gpu_brand.grid(row=10, column=1)



# Add more widgets for other features...

predict_button = Button(window, text="Guess", command=predict_price)
predict_button.grid(row=11, column=0, columnspan=2)

result_label = Label(window, text="", fg="red")
result_label.grid(row=12, column=0, columnspan=2)


# Run the Tkinter event loop
window.configure(bg='light blue')
window.mainloop()
